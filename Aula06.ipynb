# %% [markdown]
# ## Aula 06 - Dados nD - netCDF
# Nesta aula trabalhamos com dados 3 ou 4 D em formato netCDF. Utilizamos o pacote https://docs.xarray.dev/en/stable/ e trabalharemos com os dados da plataforma https://disc.gsfc.nasa.gov/
#
# ## Baixando os dados do GESDISC
# - Crie um login para você
# - Digite uma palavra-chave que descreva o dado que desejar
# - Baixe o dado para um determinado período
# https://disc.gsfc.nasa.gov/datasets/MERRA2_CNN_HAQAST_PM25_1/summary?keywords=air%20quality
# - https://github.com/nasa/gesdisc-tutorials/blob/main/notebooks/How_to_Access_GES_DISC_Data_Using_Python.ipynb

# %%
# Caminhos para a pasta de dados
import os
import numpy as np
import geopandas as gpd

pastaAtual = os.getcwd()
print(pastaAtual)

pastaDados = r"dados"
listaDados = os.listdir(pastaDados)
print(listaDados)

# Selecionando arquivos MERRA

# Selecionando arquivos do MERRA2
prefixed = [filename for filename in os.listdir(pastaDados) if filename.startswith("MERRA2")]
print(prefixed)
# Out:
# c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064
# ['.ipynb_checkpoints', '1728675725931.csv', 'BR_Pais_2022', 'MERRA2_HAQAST_CNN_L4_V1.20240505.nc4', 'MERRA2_HAQAST_CNN_L4_V1.20240506.nc4', 'metar_FOR_2023.csv', 'metar_SBFL_2013.csv', 'metar_SBFL_2014.csv', 'metar_SBFL_2015.csv', 'metar_SBFL_2016.csv', 'metar_SBFL_2017.csv', 'metar_SBFL_2018.csv', 'metar_SBFL_2019.csv', 'metar_SBFL_2020.csv', 'metar_SBFL_2021.csv', 'metar_SBFL_2022.csv', 'metar_SBFL_2023.csv', 'wd=direção do vento graus.txt']
# ['MERRA2_HAQAST_CNN_L4_V1.20240505.nc4', 'MERRA2_HAQAST_CNN_L4_V1.20240506.nc4']

# %%
# Abrir arquivos MERRA utilizando o netCDF
import netCDF4 as nc

dataset = nc.Dataset(pastaDados + '\\' + prefixed[0])
print(pastaDados + '/' + prefixed[0])
dataset
# Out:
# dados/MERRA2_HAQAST_CNN_L4_V1.20240505.nc4
# <class 'netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     Comment: filename: MERRA2_HAQAST_CNN_L4_V1_20240505.nc4
#     Filename: MERRA2_HAQAST_CNN_L4_V1_20240505.nc4
#     Conventions: CF-1
#     Institution: NASA Goddard Space Flight Center
#     References: http://gmao.gsfc.nasa.gov ; https://doi.org/10.4209/aaqr.210105 ; https://doi.org/10.1029/2022EA002375
#     Format: NetCDF-4/HDF-5
#     SpatialCoverage: global
#     VersionID: V1
#     TemporalRange: 2000-01-01 -> 2024-12-31
#     identifier_product_doi_authority: http://dx.doi.org/
#     ShortName: MERRA2_CNN_HAQAST_PM25
#     GranuleID: MERRA2_HAQAST_CNN_L4_V1_20240505.nc4
#     ProductionDateTime: 2024-06-25T01:34:15.870456Z
#     LongName: MERRA2_CNN_HAQAST bias corrected global hourly surface total PM2.5 mass concentration V1.0
#     title: MERRA2_CNN_HAQAST bias corrected global hourly surface total PM2.5 mass concentration V1.0
#     SouthernmostLatitude: -90.0
#     NorthernmostLatitude: 90.0
#     WesternmostLongitude: -180.0
#     EasternmostLongitude: 179.375
#     LatitudeResolution: 0.5
#     LongitudeResolution: 0.625
#     DataResolution: 0.5 x 0.625
#     Source: M2T1NXAER_5.12.4: BCSMASS,DUSMASS25,OCSMASS,SO2SMASS,SO4SMASS,SSSMASS25,TOTEXTTAU
#     Contact: Pawan Gupta (pawan.gupta@nasa.gov), and Alqamah Sayeed (alqamah.sayeed@nasa.gov)
#     identifier_product_doi: 10.5067/OCKK5HCFW5N3
#     RangeBeginningDate: 2024-05-05
#     RangeBeginningTime: 00:00:00.000000
#     RangeEndingDate: 2024-05-05
#     RangeEndingTime: 23:59:59.000000
#     DODS_EXTRA.Unlimited_Dimension: time
#     history: 2023-04-21 04:24:38 GMT Hyrax-1.16.3 https://goldsmr4.gesdisc.eosdis.nasa.gov/opendap/MERRA2/M2T1NXAER.5.12.4/2022/12/MERRA2_400.tavg1_2d_aer_Nx.20221231.nc4.nc4?BCSMASS,DUSMASS25,OCSMASS,SO2SMASS,SO4SMASS,SSSMASS25,TOTEXTTAU
#     ProcessingLevel: 4
#     MapProjection: Geographic lat/lon. Datum: WGS-84
#     dimensions(sizes): time(24), lat(361), lon(576)
#     variables(dimensions): int32 time(time), float32 lat(lat), float32 lon(lon), float32 MERRA2_CNN_Surface_PM25(time, lat, lon), int32 QFLAG(lat, lon)
#     groups:

# %%
# Acessando o dado de PM25

pm25 = dataset['MERRA2_CNN_Surface_PM25'][:]
print(pm25.shape)
# Out:
# (24, 361, 576)

# %%
# Plotando o dado 1D
import matplotlib.pyplot as plt

fig,ax = plt.subplots(3)

# Para o tempo - time = 0 em y =250
ax[0].plot(dataset['lon'][:],pm25[0,250,:])
print(dataset['lat'][250])

# Para o tempo - time = 0 em x =200
ax[1].plot(dataset['lat'][:],pm25[0,:,200])
print(dataset['lon'][200])

# Para todo o tempo em um ponto específico
ax[2].plot(dataset['time'][:], pm25[:,250,100])
# Out:
# 35.0
# -55.0

# %%
# Operações com o numpy
import numpy as np
import geopandas as gpd
import matplotlib
import xarray as xr

br = gpd.read_file(r"dados\BR_Pais_2022\BR_Pais_2022.shp")

fig,ax = plt.subplots(2,2)

# média do dia em todos os locais
ax[0,0].pcolor(dataset['lon'][:], dataset['lat'], np.mean(pm25,axis=0))
br.boundary.plot(ax=ax[0,0])

# máxima do dia em todos os locais
ax[0,1].pcolor(dataset['lon'][:], dataset['lat'],np.max(pm25,axis=0))
br.boundary.plot(ax=ax[0,1])
# Zoom no BR
ax[1,1].pcolor(dataset['lon'][:], dataset['lat'],np.max(pm25,axis=0),
              norm=matplotlib.colors.LogNorm())
br.boundary.plot(ax=ax[1,1])
print(br.bounds.minx)
ax[1,1].set_xlim([br.bounds.minx[0], br.bounds.maxx[0]])
ax[1,1].set_ylim([br.bounds.miny[0], br.bounds.maxy[0]])

# Máxima emissão em todas as latitudes
ax[1,0].plot(np.max(np.max(pm25[:,:,:],axis=0),axis=1), dataset['lat'][:], )
# Out:
# 0   -73.99045
# Name: minx, dtype: float64

# %%
# Abrir todos os arqu9ivos da pasta

os.chdir('../dados')
test = xr.open_mfdataset(prefixed)
test
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('C:\\Users\\alysson.assis\\OneDrive - ARAXA\\Documentos\\Tópicos especiais-Python in Environmental Applications\\ENS410064\\dados\\MERRA2_HAQAST_CNN_L4_V1.20240505.nc4',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '6565fce8-8b20-4b86-9150-c2a2c621f4a5']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 4
#       1 # Abrir todos os arqu9ivos da pasta
#       3 os.chdir('../dados')
# ----> 4 test = xr.open_mfdataset(prefixed)
#       5 test
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\api.py:1578, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1575     open_ = open_dataset
#    1576     getattr_ = getattr
# -> 1578 datasets = [open_(p, **open_kwargs) for p in paths]
#    1579 closers = [getattr_(ds, "_close") for ds in datasets]
#    1580 if preprocess is not None:
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\api.py:1578, in <listcomp>(.0)
#    1575     open_ = open_dataset
#    1576     getattr_ = getattr
# -> 1578 datasets = [open_(p, **open_kwargs) for p in paths]
#    1579 closers = [getattr_(ds, "_close") for ds in datasets]
#    1580 if preprocess is not None:
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\api.py:671, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     659 decoders = _resolve_decoders_kwargs(
#     660     decode_cf,
#     661     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     667     decode_coords=decode_coords,
#     668 )
#     670 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 671 backend_ds = backend.open_dataset(
#     672     filename_or_obj,
#     673     drop_variables=drop_variables,
#     674     **decoders,
#     675     **kwargs,
#     676 )
#     677 ds = _dataset_from_backend_dataset(
#     678     backend_ds,
#     679     filename_or_obj,
#    (...)
#     689     **kwargs,
#     690 )
#     691 return ds
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\netCDF4_.py:666, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, auto_complex, lock, autoclose)
#     644 def open_dataset(  # type: ignore[override]  # allow LSP violation, not supporting **kwargs
#     645     self,
#     646     filename_or_obj: str | os.PathLike[Any] | BufferedIOBase | AbstractDataStore,
#    (...)
#     663     autoclose=False,
#     664 ) -> Dataset:
#     665     filename_or_obj = _normalize_path(filename_or_obj)
# --> 666     store = NetCDF4DataStore.open(
#     667         filename_or_obj,
#     668         mode=mode,
#     669         format=format,
#     670         group=group,
#     671         clobber=clobber,
#     672         diskless=diskless,
#     673         persist=persist,
#     674         auto_complex=auto_complex,
#     675         lock=lock,
#     676         autoclose=autoclose,
#     677     )
#     679     store_entrypoint = StoreBackendEntrypoint()
#     680     with close_on_error(store):
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\netCDF4_.py:453, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, auto_complex, lock, lock_maker, autoclose)
#     449     kwargs["auto_complex"] = auto_complex
#     450 manager = CachingFileManager(
#     451     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     452 )
# --> 453 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\netCDF4_.py:394, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     392 self._group = group
#     393 self._mode = mode
# --> 394 self.format = self.ds.data_model
#     395 self._filename = self.ds.filepath()
#     396 self.is_remote = is_remote_uri(self._filename)
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\netCDF4_.py:462, in NetCDF4DataStore.ds(self)
#     460 @property
#     461 def ds(self):
# --> 462     return self._acquire()
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\netCDF4_.py:456, in NetCDF4DataStore._acquire(self, needs_lock)
#     455 def _acquire(self, needs_lock=True):
# --> 456     with self._manager.acquire_context(needs_lock) as root:
#     457         ds = _nc4_require_group(root, self._group, self._mode)
#     458     return ds
#
# File ~\AppData\Local\anaconda3\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src\\netCDF4\\_netCDF4.pyx:2521, in netCDF4._netCDF4.Dataset.__init__()
#
# File src\\netCDF4\\_netCDF4.pyx:2158, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\alysson.assis\\OneDrive - ARAXA\\Documentos\\Tópicos especiais-Python in Environmental Applications\\ENS410064\\dados\\MERRA2_HAQAST_CNN_L4_V1.20240505.nc4'

# %%
# Verifique o diretório atual e a existência da pasta
os.chdir('../dados')
print(os.getcwd())  # Mostra o caminho atual
print(os.listdir('.'))  # Lista os arquivos no diretório atual

# Usando um padrão ou lista de arquivos
prefixed = "*.nc4"  # ou forneça uma lista de caminhos completos
test = xr.open_mfdataset(prefixed, combine="by_coords")
print(test)
# Out:
# C:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\dados
# ['.ipynb_checkpoints', '1728675725931.csv', 'BR_Pais_2022', 'MERRA2_HAQAST_CNN_L4_V1.20240505.nc4', 'MERRA2_HAQAST_CNN_L4_V1.20240506.nc4', 'metar_FOR_2023.csv', 'metar_SBFL_2013.csv', 'metar_SBFL_2014.csv', 'metar_SBFL_2015.csv', 'metar_SBFL_2016.csv', 'metar_SBFL_2017.csv', 'metar_SBFL_2018.csv', 'metar_SBFL_2019.csv', 'metar_SBFL_2020.csv', 'metar_SBFL_2021.csv', 'metar_SBFL_2022.csv', 'metar_SBFL_2023.csv', 'wd=direção do vento graus.txt']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('C:\\Users\\alysson.assis\\OneDrive - ARAXA\\Documentos\\Tópicos especiais-Python in Environmental Applications\\ENS410064\\dados\\MERRA2_HAQAST_CNN_L4_V1.20240505.nc4',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), 'e2a43d16-44a5-44e8-8827-83669f7761f8']
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 8
#       6 # Usando um padrão ou lista de arquivos
#       7 prefixed = "*.nc4"  # ou forneça uma lista de caminhos completos
# ----> 8 test = xr.open_mfdataset(prefixed, combine="by_coords")
#       9 print(test)
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\api.py:1578, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1575     open_ = open_dataset
#    1576     getattr_ = getattr
# -> 1578 datasets = [open_(p, **open_kwargs) for p in paths]
#    1579 closers = [getattr_(ds, "_close") for ds in datasets]
#    1580 if preprocess is not None:
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\api.py:1578, in <listcomp>(.0)
#    1575     open_ = open_dataset
#    1576     getattr_ = getattr
# -> 1578 datasets = [open_(p, **open_kwargs) for p in paths]
#    1579 closers = [getattr_(ds, "_close") for ds in datasets]
#    1580 if preprocess is not None:
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\api.py:671, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     659 decoders = _resolve_decoders_kwargs(
#     660     decode_cf,
#     661     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     667     decode_coords=decode_coords,
#     668 )
#     670 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 671 backend_ds = backend.open_dataset(
#     672     filename_or_obj,
#     673     drop_variables=drop_variables,
#     674     **decoders,
#     675     **kwargs,
#     676 )
#     677 ds = _dataset_from_backend_dataset(
#     678     backend_ds,
#     679     filename_or_obj,
#    (...)
#     689     **kwargs,
#     690 )
#     691 return ds
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\netCDF4_.py:666, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, auto_complex, lock, autoclose)
#     644 def open_dataset(  # type: ignore[override]  # allow LSP violation, not supporting **kwargs
#     645     self,
#     646     filename_or_obj: str | os.PathLike[Any] | BufferedIOBase | AbstractDataStore,
#    (...)
#     663     autoclose=False,
#     664 ) -> Dataset:
#     665     filename_or_obj = _normalize_path(filename_or_obj)
# --> 666     store = NetCDF4DataStore.open(
#     667         filename_or_obj,
#     668         mode=mode,
#     669         format=format,
#     670         group=group,
#     671         clobber=clobber,
#     672         diskless=diskless,
#     673         persist=persist,
#     674         auto_complex=auto_complex,
#     675         lock=lock,
#     676         autoclose=autoclose,
#     677     )
#     679     store_entrypoint = StoreBackendEntrypoint()
#     680     with close_on_error(store):
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\netCDF4_.py:453, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, auto_complex, lock, lock_maker, autoclose)
#     449     kwargs["auto_complex"] = auto_complex
#     450 manager = CachingFileManager(
#     451     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     452 )
# --> 453 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\netCDF4_.py:394, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     392 self._group = group
#     393 self._mode = mode
# --> 394 self.format = self.ds.data_model
#     395 self._filename = self.ds.filepath()
#     396 self.is_remote = is_remote_uri(self._filename)
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\netCDF4_.py:462, in NetCDF4DataStore.ds(self)
#     460 @property
#     461 def ds(self):
# --> 462     return self._acquire()
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\netCDF4_.py:456, in NetCDF4DataStore._acquire(self, needs_lock)
#     455 def _acquire(self, needs_lock=True):
# --> 456     with self._manager.acquire_context(needs_lock) as root:
#     457         ds = _nc4_require_group(root, self._group, self._mode)
#     458     return ds
#
# File ~\AppData\Local\anaconda3\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\file_manager.py:199, in CachingFileManager.acquire_context(self, needs_lock)
#     196 @contextlib.contextmanager
#     197 def acquire_context(self, needs_lock=True):
#     198     """Context manager for acquiring a file."""
# --> 199     file, cached = self._acquire_with_cache_info(needs_lock)
#     200     try:
#     201         yield file
#
# File c:\Users\alysson.assis\OneDrive - ARAXA\Documentos\Tópicos especiais-Python in Environmental Applications\ENS410064\pyEnv\lib\site-packages\xarray\backends\file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File src\\netCDF4\\_netCDF4.pyx:2521, in netCDF4._netCDF4.Dataset.__init__()
#
# File src\\netCDF4\\_netCDF4.pyx:2158, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\alysson.assis\\OneDrive - ARAXA\\Documentos\\Tópicos especiais-Python in Environmental Applications\\ENS410064\\dados\\MERRA2_HAQAST_CNN_L4_V1.20240505.nc4'
